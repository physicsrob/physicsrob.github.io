# %%
#hide
import keras
from keras import backend as K
from keras.datasets import mnist
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Reshape, Input
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, Conv2DTranspose
from keras.layers import LeakyReLU

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

num_classes = 10
img_rows, img_cols = 28, 28
latent_size = 32
# Out:
# Using TensorFlow backend.

# %%
#hide
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %%
def make_gen():
    model = Sequential()
    model.add(Dense(7 *7 * 10, input_dim=latent_size, activation='relu'))
#    model.add(Dense(7 * 7 * 10))
#    model.add(LeakyReLU(alpha=0.1))

    model.add(Reshape((7,7,10)))
    model.add(BatchNormalization())
    model.add(Conv2DTranspose(64, kernel_size=(5,5), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.1))
    model.add(BatchNormalization())
    model.add(Conv2DTranspose(16, kernel_size=(5,5), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.1))
    model.add(BatchNormalization())
    model.add(Conv2D(1, kernel_size=(5,5), strides=(1,1),
                              activation='sigmoid', padding='same'))
    return model

# %%
gen=make_gen()

# %%
# untrained generator image
x=gen.predict(np.random.rand(1,32))
print("Shape: ", x.shape)
plt.imshow(x[0].reshape(28,28), cmap='gray_r')
plt.show()
# Out:
# Shape:  (1, 28, 28, 1)

# %%
def make_desc():
    model = Sequential()
    model.add(Conv2D(8, kernel_size=(3, 3),
                     input_shape=(28,28,1), padding='same'))
    model.add(LeakyReLU(alpha=0.1))
    model.add(AveragePooling2D(pool_size=(2, 2)))
#    model.add(BatchNormalization())
    model.add(Conv2D(16, (3, 3), padding='same'))
    model.add(LeakyReLU(alpha=0.1))
    model.add(AveragePooling2D(pool_size=(2, 2)))
#    model.add(BatchNormalization())
#    model.add(Conv2D(128, (3, 3), padding='same'))
#    model.add(LeakyReLU(alpha=0.1))
#    model.add(BatchNormalization())
#    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
#    model.add(Dropout(0.1))
    model.add(Dense(128))
    model.add(LeakyReLU(alpha=0.1))
#    model.add(BatchNormalization())
#    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
desc=make_desc()

# %%
desc.predict(x_train[0:10])
# Out:
# array([[0.49688634],
#        [0.48754084],
#        [0.5041157 ],
#        [0.50128186],
#        [0.49865994],
#        [0.49966425],
#        [0.49554947],
#        [0.50007796],
#        [0.49665993],
#        [0.5078781 ]], dtype=float32)

# %%
desc.compile(loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
def gen_fake_images(gen, n):
    noise = np.random.normal(size=(n, latent_size))
    return gen.predict(noise)

def train_desc_on_gen(gen, desc):
    batch_size = 100
    imgs = gen_fake_images(gen, batch_size)
    desc.train_on_batch(imgs, np.zeros(batch_size).reshape(batch_size,1))

# %%
def train_desc_on_real(desc, imgs):
    desc.train_on_batch(imgs, 0.9*np.ones(len(imgs)).reshape(len(imgs),1))

# %%
train_desc_on_gen(gen,desc)

# %%
train_desc_on_real(desc,x_train[0:100])

# %%
def eval_desc(desc):
    print("Evaluating descriminator for real images")
    ev=desc.evaluate(x_train, np.ones(len(x_train)), 500)
    print("Evaluation: ", ev)
    print("Evaluating generator")
    fake_imgs = gen_fake_images(gen, 500)
    ev=desc.evaluate(fake_imgs, np.ones(len(fake_imgs)))
    print("Evaluation: ", ev)

# %%
eval_desc(desc)
# Out:
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 8us/step
# Evaluation:  [0.7286900485555331, 0.005716666775212312]
# Evaluating generator
# 500/500 [==============================] - 0s 83us/step
# Evaluation:  [0.8339492411613464, 0.0]

# %%
fakeos = gen_fake_images(gen, 1)

# %%
desc.predict(fakeos)
# Out:
# array([[0.43430257]], dtype=float32)

# %%
latent = Input(shape=(latent_size, ))
desc.trainable = False
combined = Model(latent, desc(gen(latent)))
combined.compile(loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
def train_gen(combined):
    batch_size = 100
    noise = np.random.normal(size=(batch_size, latent_size))
    combined.train_on_batch(noise, 0.95*np.ones((batch_size,1)))

# %%
train_gen(combined)

# %%
batch_size=100
for epoch in range(50):
    offset_start = 0
    for step in range(1000):
        offset_start += batch_size
        if (offset_start + batch_size) >= len(x_train): offset_start = 0
        offset_end = offset_start + batch_size
        real_imgs = x_train[offset_start:offset_end]
        fake_imgs = gen_fake_images(gen, batch_size)
        real_img_targets = 0.95*np.ones(batch_size).reshape(batch_size,1)
        fake_img_targets = 0.05*np.ones(batch_size).reshape(batch_size,1)
        imgs = np.concatenate((real_imgs, fake_imgs))
        targets = np.concatenate((real_img_targets, fake_img_targets))
        desc.train_on_batch(imgs, targets)
        train_gen(combined)
#    print("Training disc:")
 #   img = gen_fake_images(gen, 1)[0]
    eval_desc(desc)
#    print("Training gen:")
#    for step in range(1000):
    imgs = gen_fake_images(gen, 2)
 #   print("Fake images mean: ", np.mean(imgs))
    for i in range(2):
        plt.imshow(imgs[i].reshape(28,28), cmap='gray_r')
        plt.show()
    eval_desc(desc)
# Out:
# /home/rob/.local/lib/python3.6/site-packages/keras/engine/training.py:478: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.4026995475093524, 0.8376000002026558]
# Evaluating generator
# 500/500 [==============================] - 0s 53us/step
# Evaluation:  [1.6012481231689453, 0.1880000002384186]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.4026995475093524, 0.8376000002026558]
# Evaluating generator
# 500/500 [==============================] - 0s 51us/step
# Evaluation:  [1.5859554662704467, 0.15200000047683715]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.549420349051555, 0.6943166633447011]
# Evaluating generator
# 500/500 [==============================] - 0s 54us/step
# Evaluation:  [1.0988840827941895, 0.14200000023841858]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.549420349051555, 0.6943166633447011]
# Evaluating generator
# 500/500 [==============================] - 0s 59us/step
# Evaluation:  [1.0933141269683837, 0.15800000002980233]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.46490128288666405, 0.7804166674613953]
# Evaluating generator
# 500/500 [==============================] - 0s 51us/step
# Evaluation:  [0.7859352178573609, 0.4579999997615814]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.46490128288666405, 0.7804166674613953]
# Evaluating generator
# 500/500 [==============================] - 0s 70us/step
# Evaluation:  [0.7545009651184083, 0.5120000009536743]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.5531057504316171, 0.7139333342512448]
# Evaluating generator
# 500/500 [==============================] - 0s 46us/step
# Evaluation:  [1.0245285234451293, 0.19600000005960463]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.5531057504316171, 0.7139333342512448]
# Evaluating generator
# 500/500 [==============================] - 0s 72us/step
# Evaluation:  [1.0141929883956908, 0.19200000005960466]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.2960833073904117, 0.8754833335677783]
# Evaluating generator
# 500/500 [==============================] - 0s 53us/step
# Evaluation:  [1.2922481002807618, 0.1520000002384186]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.2960833073904117, 0.8754833335677783]
# Evaluating generator
# 500/500 [==============================] - 0s 53us/step
# Evaluation:  [1.3039090404510498, 0.16400000002980233]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.4624281994998455, 0.7848500003417332]
# Evaluating generator
# 500/500 [==============================] - 0s 51us/step
# Evaluation:  [0.8912081613540649, 0.3600000002384186]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.4624281994998455, 0.7848500003417332]
# Evaluating generator
# 500/500 [==============================] - 0s 29us/step
# Evaluation:  [0.8968019604682922, 0.32000000023841857]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.40173291924099125, 0.8180999979376793]
# Evaluating generator
# 500/500 [==============================] - 0s 52us/step
# Evaluation:  [0.8871556787490845, 0.4360000004768372]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.40173291924099125, 0.8180999979376793]
# Evaluating generator
# 500/500 [==============================] - 0s 46us/step
# Evaluation:  [0.8999114999771118, 0.42800000023841855]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.2361652382959922, 0.9085666631658872]
# Evaluating generator
# 500/500 [==============================] - 0s 50us/step
# Evaluation:  [1.2729767379760741, 0.22000000002980233]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.2361652382959922, 0.9085666631658872]
# Evaluating generator
# 500/500 [==============================] - 0s 64us/step
# Evaluation:  [1.2516372060775758, 0.232]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 7us/step
# Evaluation:  [0.5614907585084439, 0.6837499986092249]
# Evaluating generator
# 500/500 [==============================] - 0s 76us/step
# Evaluation:  [1.1209784259796143, 0.17800000002980232]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.5614907585084439, 0.6837499986092249]
# Evaluating generator
# 500/500 [==============================] - 0s 99us/step
# Evaluation:  [1.0986115274429322, 0.20800000023841858]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.5689380536476771, 0.6696333328882853]
# Evaluating generator
# 500/500 [==============================] - 0s 52us/step
# Evaluation:  [1.1387770938873292, 0.198]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.5689380536476771, 0.6696333328882853]
# Evaluating generator
# 500/500 [==============================] - 0s 49us/step
# Evaluation:  [1.1356375494003297, 0.1840000002384186]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.5655748330056667, 0.6689499994119008]
# Evaluating generator
# 500/500 [==============================] - 0s 41us/step
# Evaluation:  [1.1648711948394774, 0.19600000023841857]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.5655748330056667, 0.6689499994119008]
# Evaluating generator
# 500/500 [==============================] - 0s 51us/step
# Evaluation:  [1.1814546146392821, 0.1940000001192093]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.3673118078460296, 0.8386666665474574]
# Evaluating generator
# 500/500 [==============================] - 0s 62us/step
# Evaluation:  [0.8699583897590637, 0.45800000047683714]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.3673118078460296, 0.8386666665474574]
# Evaluating generator
# 500/500 [==============================] - 0s 62us/step
# Evaluation:  [0.8804587397575379, 0.44399999976158144]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.4397141742209593, 0.7733999987443289]
# Evaluating generator
# 500/500 [==============================] - 0s 61us/step
# Evaluation:  [1.016558150291443, 0.30200000023841855]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.4397141742209593, 0.7733999987443289]
# Evaluating generator
# 500/500 [==============================] - 0s 60us/step
# Evaluation:  [1.0024688959121704, 0.3160000001192093]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 8us/step
# Evaluation:  [0.4778173714876175, 0.7478999997178714]
# Evaluating generator
# 500/500 [==============================] - 0s 78us/step
# Evaluation:  [1.023819652557373, 0.27800000047683715]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.4778173714876175, 0.7478999997178714]
# Evaluating generator
# 500/500 [==============================] - 0s 62us/step
# Evaluation:  [1.020097848892212, 0.2800000000298023]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.39401479860146843, 0.814950001736482]
# Evaluating generator
# 500/500 [==============================] - 0s 54us/step
# Evaluation:  [1.0119315037727357, 0.30399999976158143]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.39401479860146843, 0.814950001736482]
# Evaluating generator
# 500/500 [==============================] - 0s 52us/step
# Evaluation:  [1.0280209217071534, 0.248]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.4058207988739014, 0.7920666669805845]
# Evaluating generator
# 500/500 [==============================] - 0s 56us/step
# Evaluation:  [1.1262586908340455, 0.23600000023841858]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.4058207988739014, 0.7920666669805845]
# Evaluating generator
# 500/500 [==============================] - 0s 50us/step
# Evaluation:  [1.1232162470817566, 0.22599999976158142]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.44355698029200236, 0.765833334128062]
# Evaluating generator
# 500/500 [==============================] - 0s 47us/step
# Evaluation:  [1.11885018157959, 0.22400000005960463]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.44355698029200236, 0.765833334128062]
# Evaluating generator
# 500/500 [==============================] - 0s 53us/step
# Evaluation:  [1.093652823448181, 0.2200000002384186]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.3628685255845388, 0.818900000055631]
# Evaluating generator
# 500/500 [==============================] - 0s 55us/step
# Evaluation:  [0.9578249597549439, 0.35199999952316285]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.3628685255845388, 0.818900000055631]
# Evaluating generator
# 500/500 [==============================] - 0s 36us/step
# Evaluation:  [1.0051754131317139, 0.31999999976158144]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 7us/step
# Evaluation:  [0.40008867184321084, 0.7900666683912277]
# Evaluating generator
# 500/500 [==============================] - 0s 61us/step
# Evaluation:  [1.0257500162124633, 0.2900000002384186]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.40008867184321084, 0.7900666683912277]
# Evaluating generator
# 500/500 [==============================] - 0s 61us/step
# Evaluation:  [1.0767427291870117, 0.276]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.4199224387605985, 0.7872999990979831]
# Evaluating generator
# 500/500 [==============================] - 0s 51us/step
# Evaluation:  [1.1185017757415772, 0.23400000047683717]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.4199224387605985, 0.7872999990979831]
# Evaluating generator
# 500/500 [==============================] - 0s 52us/step
# Evaluation:  [1.065423387527466, 0.26400000011920927]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.345773587624232, 0.8477666685978572]
# Evaluating generator
# 500/500 [==============================] - 0s 57us/step
# Evaluation:  [0.9382241725921631, 0.34800000047683716]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.345773587624232, 0.8477666685978572]
# Evaluating generator
# 500/500 [==============================] - 0s 71us/step
# Evaluation:  [0.9749676103591919, 0.32]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.451904458552599, 0.7428833325703939]
# Evaluating generator
# 500/500 [==============================] - 0s 46us/step
# Evaluation:  [1.1120841732025146, 0.24400000011920928]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.451904458552599, 0.7428833325703939]
# Evaluating generator
# 500/500 [==============================] - 0s 61us/step
# Evaluation:  [1.0844150457382202, 0.2520000001192093]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.41247627064585685, 0.7866000001629193]
# Evaluating generator
# 500/500 [==============================] - 0s 52us/step
# Evaluation:  [1.0586569213867187, 0.28800000047683716]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.41247627064585685, 0.7866000001629193]
# Evaluating generator
# 500/500 [==============================] - 0s 77us/step
# Evaluation:  [1.0626046380996703, 0.268]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.4803934966524442, 0.7134666661421458]
# Evaluating generator
# 500/500 [==============================] - 0s 50us/step
# Evaluation:  [1.2114474048614503, 0.17400000023841858]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.4803934966524442, 0.7134666661421458]
# Evaluating generator
# 500/500 [==============================] - 0s 48us/step
# Evaluation:  [1.1783477439880372, 0.1740000001192093]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.34666149790088335, 0.8405166685581207]
# Evaluating generator
# 500/500 [==============================] - 0s 48us/step
# Evaluation:  [0.9680202445983886, 0.31799999976158144]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.34666149790088335, 0.8405166685581207]
# Evaluating generator
# 500/500 [==============================] - 0s 45us/step
# Evaluation:  [0.9647901849746704, 0.3040000004768372]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 6us/step
# Evaluation:  [0.42456573819120724, 0.7657666678229967]
# Evaluating generator
# 500/500 [==============================] - 0s 61us/step
# Evaluation:  [1.1682183618545532, 0.20599999976158143]
# Evaluating descriminator for real images
# 60000/60000 [==============================] - 0s 5us/step
# Evaluation:  [0.42456573819120724, 0.7657666678229967]
# Evaluating generator
# 500/500 [==============================] - 0s 50us/step
# Evaluation:  [1.1655239191055298, 0.22400000023841857]

# %%
train_gen(combined); eval_desc(desc)

# %%
for i in range(5000): train_gen(combined)

# %%
np.mean(x_test[0])

# %%
np.amin(x_test)

# %%
combined.predict(np.random.normal(size=(10,32)))

# %%
for i in range(100): train_gen(combined)

# %%
np.mean(gen.predict(np.random.normal(size=(10,32))))

# %%
gen.train_on_batch(np.random.normal(size=(10,32)), np.zeros(10*28*28).reshape(10,28,28,1))

# %%
gen.compile(loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
np.mean(x_test)

# %%
plt.imshow(x_train[0].reshape(28,28), cmap='gray_r')

# %%
np.mean(x_train)

# %%
for i in range(100): gen.train_on_batch(np.random.normal(size=(1,32)), x_train[0:1])
